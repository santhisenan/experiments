# %%
import nibabel as nib

# %%
epi_image = nib.load("/Users/santhisenan/Documents/Datasets/nifti_sample/someones_epi.nii.gz")

# %%
epi_image_data = epi_image.get_fdata()

# %%
epi_image_data.shape
# Out:
# (53, 61, 33)

# %%
import matplotlib.pyplot as plt

# %%
def show_slices(slices):
    fig, axes = plt.subplots(1, len(slices))
    for i, slice in enumerate(slices):
        axes[i].imshow(slice.T, cmap="gray", origin="lower")

# %%
slice_0 = epi_image_data[26, :, :]
slice_1 = epi_image_data[:, 30, :]
slice_2 = epi_image_data[:, :, 16]

# %%
show_slices([slice_0, slice_1, slice_2])

# %%
anatomical_image = nib.load("/Users/santhisenan/Documents/Datasets/nifti_sample/someones_anatomy.nii.gz")
anatomical_image_data = anatomical_image.get_fdata()

# %%
anatomical_image_data.shape
# Out:
# (57, 67, 56)

# %%
show_slices([anatomical_image_data[28, :, :],
             anatomical_image_data[:, 33, :],
             anatomical_image_data[:, :, 28]])
